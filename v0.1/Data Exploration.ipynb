# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/PHD/SemEval2023
# Out:
# /content/gdrive/MyDrive/PHD/SemEval2023

# %%
ls Data/starting_ki
# Out:
# EXAMPLE_SUBMISSION_dev_task_a.zip  gab_1M_unlabelled.csv
# EXAMPLE_SUBMISSION_dev_task_b.zip  reddit_1M_unlabelled.csv
# EXAMPLE_SUBMISSION_dev_task_c.zip  train_all_tasks.csv

# %%
import pandas as pd

# dfa = pd.read_csv("Data/dev_task_a_entries.csv")
# dfb = pd.read_csv("Data/dev_task_b_entries.csv")
# dfc = pd.read_csv("Data/dev_task_c_entries.csv")

# %%
data = pd.read_csv("Data/starting_ki/train_all_tasks.csv")

# %%
data
# Out:
#                       rewire_id  \
# 0       sexism2022_english-7358
# 1       sexism2022_english-2367
# 2       sexism2022_english-3073
# 3      sexism2022_english-14895
# 4       sexism2022_english-4118
# ...                         ...
# 13995  sexism2022_english-14185
# 13996  sexism2022_english-18629
# 13997   sexism2022_english-3320
# 13998  sexism2022_english-13309
# 13999  sexism2022_english-12402
#
#                                                     text label_sexist  \
# 0                  Damn, this writing was pretty chaotic   not sexist
# 1      Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2           How the FUCK is this woman still an MP!!!???   not sexist
# 3      Understand. Know you're right. At same time I ...   not sexist
# 4         Surprized they didn't stop and rape some women   not sexist
# ...                                                  ...          ...
# 13995  complexes like the 'nice chicks' that go after...       sexist
# ...

# %%
data[["text", "label_category"]].groupby("label_category").count()
# Out:
#                                            text
# label_category
# 1. threats, plans to harm and incitement    310
# 2. derogation                              1590
# 3. animosity                               1165
# 4. prejudiced discussions                   333
# none                                      10602

# %%
data[["text", "label_category", "label_vector"]].groupby(["label_category", "label_vector"]).count()
# Out:
#                                                                                               text
# label_category                           label_vector
# 1. threats, plans to harm and incitement 1.1 threats of harm                                    56
#                                          1.2 incitement and encouragement of harm              254
# 2. derogation                            2.1 descriptive attacks                               717
#                                          2.2 aggressive and emotive attacks                    673
#                                          2.3 dehumanising attacks & overt sexual objecti...    200
# 3. animosity                             3.1 casual use of gendered slurs, profanities, ...    637
#                                          3.2 immutable gender differences and gender ste...    417
#                                          3.3 backhanded gendered compliments                    64
# ...
