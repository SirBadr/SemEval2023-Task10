# %%
data_path = "./Data/starting_ki/train_all_tasks.csv"

# %%
import pandas as pd
data = pd.read_csv(data_path)
data = data[data["label_category"]!="none"]

# %%
data
# Out:
#                       rewire_id  \
# 8      sexism2022_english-10142
# 11       sexism2022_english-760
# 17      sexism2022_english-1108
# 18     sexism2022_english-10099
# 19     sexism2022_english-10014
# ...                         ...
# 13977  sexism2022_english-19317
# 13990  sexism2022_english-15667
# 13993   sexism2022_english-1400
# 13994   sexism2022_english-4515
# 13995  sexism2022_english-14185
#
#                                                     text label_sexist  \
# 8      just the inside of your wallet: cash, bank car...       sexist
# 11     They get the initial chance because they are a...       sexist
# 17                       ugly chicks A pussy is a pussy.       sexist
# 18     fuck her off with a nine mm this is what you g...       sexist
# 19     How about I talk shit to an idiot like you? Ar...       sexist
# ...                                                  ...          ...
# 13977  Another Democrat with signal eyeglasses.There ...       sexist
# 13990  “We’re f—ing your grandmother, that’s what we ...       sexist
# 13993  Never forget, it's always the man's fault. Nev...       sexist
# 13994  lol india is on some next level simp shit. The...       sexist
# 13995  complexes like the 'nice chicks' that go after...       sexist
#
#                                  label_category  \
# 8                                 2. derogation
# 11                                2. derogation
# 17                                2. derogation
# 18     1. threats, plans to harm and incitement
# 19                                 3. animosity
# ...                                         ...
# 13977                             2. derogation
# 13990                              3. animosity
# 13993                 4. prejudiced discussions
# 13994                             2. derogation
# 13995                             2. derogation
#
#                                             label_vector
# 8      2.3 dehumanising attacks & overt sexual object...
# 11                               2.1 descriptive attacks
# 17     2.3 dehumanising attacks & overt sexual object...
# 18              1.2 incitement and encouragement of harm
# 19     3.1 casual use of gendered slurs, profanities,...
# ...                                                  ...
# 13977                            2.1 descriptive attacks
# 13990  3.1 casual use of gendered slurs, profanities,...
# 13993  4.2 supporting systemic discrimination against...
# 13994                 2.2 aggressive and emotive attacks
# 13995                            2.1 descriptive attacks
#
# [3398 rows x 5 columns]

# %%
label_category_map = {
    "1. threats, plans to harm and incitement":"Threat",
    "2. derogation":"Derogation",
    "3. animosity":"Animosity",
    "4. prejudiced discussions":"Prejudiced discussion",
    "Threat":"1. threats, plans to harm and incitement",
    "Derogation":"2. derogation",
    "Animosity":"3. animosity",
    "Prejudiced discussion":"4. prejudiced discussions"
}
print(label_category_map["4. prejudiced discussions"])
# Out:
# Prejudiced discussion

# %%
import random
# function returns two random text samples to use them as GPT-J prompt
def get_three_random_samples(data_frame):
    # get two random samples from `data file`
    s1, s2, s3 = random.sample(range(0, len(data)), 3)
    # get text labels
    label1 = label_category_map[data_frame['label_category'].iloc[s1]]
    label2 = label_category_map[data_frame['label_category'].iloc[s2]]
    label3 = label_category_map[data_frame['label_category'].iloc[s3]]
#     print(label_category_map[label1])
    
    # return text1, label1, text2, label2
    return data_frame['text'].iloc[s1], label1, data_frame['text'].iloc[s2], label2, data_frame['text'].iloc[s3], label3

# %%
print(get_three_random_samples(data))
# Out:
# ('Is the ultimate metaphor for the female psyche? It might be.... a classless, shameful act to garner attention at any cost. The male ego pales to the narcissism of the female ego. Fuck em and feed em beans, I say', 'Derogation', 'Is the ultimate metaphor for the female psyche? It might be.... a classless, shameful act to garner attention at any cost. The male ego pales to the narcissism of the female ego. Fuck em and feed em beans, I say', 'Animosity', 'yeah, also I have no statistical data but from anecdotical evidence obese girls seem to be into men who are even more high T and muscular than average girls, depite having a much lower smv themselves', 'Animosity')

# %%
def get_prompt(text1, label1, text2, label2, text3, label3):
    # define a function that takes as input three samples and generates the prompt
    # that we should pass to the GPT-3 language model for completion.
    description = "Each item in the following list contains a tweet and the respective category. Category is one of 'Threat', 'Derogation', 'Animosity', or 'Prejudiced discussion'"
    prompt = (f"{description}\n"
            f"Tweet: {text1} (Sentiment: {label1})\n"
            f"Tweet: {text2} (Sentiment: {label2})\n"
            f"Tweet: {text3} (Sentiment: {label3})\n"
            f"Tweet:")
    return prompt

# %%
a,b,c,d,e,f=get_three_random_samples(data)
get_prompt(a,b,c,d,e,f)
# Out:
# "Each item in the following list contains a tweet and the respective category. Category is one of 'Threat', 'Derogation', 'Animosity', or 'Prejudiced discussion'\nTweet: Poor chris, but the bitch got what she deserved, named and shamed on public radio for being a cheating cunt (Sentiment: Derogation)\nTweet: Poor chris, but the bitch got what she deserved, named and shamed on public radio for being a cheating cunt (Sentiment: Derogation)\nTweet: [USER] Chocolate is a real bitch. You can yell n scream all you want, chocolate gives no fucks! ...and she has mean deplorable friends too. #GabChefs (Sentiment: Animosity)\nTweet:"

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, TrainerCallback, AutoModelForCausalLM, AutoModelForSeq2SeqLM
max_input_len = 30
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-j-6B")
# Out:
# Downloading:   0%|          | 0.00/619 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     627 while not is_fp_closed(self._fp):
# --> 628     data = self.read(amt=amt, decode_content=decode_content)
#     630     if data:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:566, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
# --> 566 with self._error_catcher():
#     567     data = self._fp_read(amt) if not fp_closed else b""
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/urllib3/response.py:449, in HTTPResponse._error_catcher(self)
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
# --> 449     raise ReadTimeoutError(self._pool, None, "Read timed out.")
#     451 except BaseSSLError as e:
#     452     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[74], line 3
#       1 from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, TrainerCallback, AutoModelForCausalLM, AutoModelForSeq2SeqLM
#       2 max_input_len = 30
# ----> 3 tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
#       4 model = AutoModelForCausalLM.from_pretrained("EleutherAI/gpt-j-6B")
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:619, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     615     if tokenizer_class is None:
#     616         raise ValueError(
#     617             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     618         )
# --> 619     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     621 # Otherwise we have to be creative.
#     622 # if model is an encoder decoder, the encoder tokenizer class is used by default
#     623 if isinstance(config, EncoderDecoderConfig):
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1736, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1734             resolved_vocab_files[file_id] = download_url(file_path, proxies=proxies)
#    1735     else:
# -> 1736         resolved_vocab_files[file_id] = cached_file(
#    1737             pretrained_model_name_or_path,
#    1738             file_path,
#    1739             cache_dir=cache_dir,
#    1740             force_download=force_download,
#    1741             proxies=proxies,
#    1742             resume_download=resume_download,
#    1743             local_files_only=local_files_only,
#    1744             use_auth_token=use_auth_token,
#    1745             user_agent=user_agent,
#    1746             revision=revision,
#    1747             subfolder=subfolder,
#    1748             _raise_exceptions_for_missing_entries=False,
#    1749             _raise_exceptions_for_connection_errors=False,
#    1750             _commit_hash=commit_hash,
#    1751         )
#    1752         commit_hash = extract_commit_hash(resolved_vocab_files[file_id], commit_hash)
#    1754 if len(unresolved_files) > 0:
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/transformers/utils/hub.py:409, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     406 user_agent = http_user_agent(user_agent)
#     407 try:
#     408     # Load from URL or cache if already cached
# --> 409     resolved_file = hf_hub_download(
#     410         path_or_repo_id,
#     411         filename,
#     412         subfolder=None if len(subfolder) == 0 else subfolder,
#     413         revision=revision,
#     414         cache_dir=cache_dir,
#     415         user_agent=user_agent,
#     416         force_download=force_download,
#     417         proxies=proxies,
#     418         resume_download=resume_download,
#     419         use_auth_token=use_auth_token,
#     420         local_files_only=local_files_only,
#     421     )
#     423 except RepositoryNotFoundError:
#     424     raise EnvironmentError(
#     425         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     426         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     427         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     428         "`huggingface-cli login` and pass `use_auth_token=True`."
#     429     )
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:124, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     119 if check_use_auth_token:
#     120     kwargs = smoothly_deprecate_use_auth_token(
#     121         fn_name=fn.__name__, has_token=has_token, kwargs=kwargs
#     122     )
# --> 124 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/huggingface_hub/file_download.py:1242, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1239 with temp_file_manager() as temp_file:
#    1240     logger.info("downloading %s to %s", url, temp_file.name)
# -> 1242     http_get(
#    1243         url_to_download,
#    1244         temp_file,
#    1245         proxies=proxies,
#    1246         resume_size=resume_size,
#    1247         headers=headers,
#    1248     )
#    1250 logger.info("storing %s in cache at %s", url, blob_path)
#    1251 _chmod_and_replace(temp_file.name, blob_path)
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/huggingface_hub/file_download.py:495, in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     486 total = resume_size + int(content_length) if content_length is not None else None
#     487 progress = tqdm(
#     488     unit="B",
#     489     unit_scale=True,
#    (...)
#     493     disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     494 )
# --> 495 for chunk in r.iter_content(chunk_size=1024):
#     496     if chunk:  # filter out keep-alive new chunks
#     497         progress.update(len(chunk))
#
# File ~/opt/anaconda3/envs/SemEval22BackUp/lib/python3.10/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820     raise ContentDecodingError(e)
#     821 except ReadTimeoutError as e:
# --> 822     raise ConnectionError(e)
#     823 except SSLError as e:
#     824     raise RequestsSSLError(e)
#
# ConnectionError: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.

# %%
# block of code to generate Synthetic Tweets!
# define the number of synthetic samples to generate
n = 100
new_texts = []
new_labels = []

iter = 0
while iter < n:
    # select two random samples from training set
    text1, label1, text2, label2, text3, label3 = get_three_random_samples(data)
    # create the prompt
    prompt = get_prompt(text1, label1, text2, label2, text3, label3)

    # generate text using GPT-J model
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids
    print('before_gentokens')
    gen_tokens = model.generate(input_ids, do_sample=True, temperature=0.9, max_length=100,)
    print('after_gentokens')
    gen_text = tokenizer.batch_decode(gen_tokens)[0]
    # the generated output will be in the form "<text> (Sentiment: <label>)"
    data = gen_text.split('\n')[3].strip('Tweet: ').split('(Category:')
    if len(data) < 2:
        # the format of the response is invalid
        continue

    text = data[0]
    label = data[1].split(')')[0].strip()
    if label not in ['Threat', 'Derogation', 'Animosity', 'Prejudiced discussion']:
        # the format of the response is invalid
        continue
    print('text', text);
    new_texts.append(text)
    new_labels.append(label)
    iter += 1
    # append synthetic data to tweets dataframe to use them in augmentation!
    new_row = {'rewire_id':'GPTJ-SyntheticData',
               'text':text,
               'label_sexist':'sexist',
               'label_category':label_category_map[label],
               'label_vector':'none'}
    append_to_dataframe(data, new_row)
# define the synthetic dataset and save it to disk 
synthetic_ds = Dataset.from_dict({'text': new_texts, 'label': new_labels})
synthetic_ds.save_to_disk('./gpt-j-generated-tweets/' + str(n))

# %%
def append_to_dataframe(data, row):
    data = data.append(row, ignore_index=True)

# %%
data.columns
# Out:
# Index(['rewire_id', 'text', 'label_sexist', 'label_category', 'label_vector'], dtype='object')
