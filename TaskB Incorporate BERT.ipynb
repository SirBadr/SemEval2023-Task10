# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/SemEval2023/SemEval2022-Task10/re_run
# Out:
# /content/gdrive/.shortcut-targets-by-id/1lC-ZKLaCDQyfLcof2Ak7FDa6IvTt318A/SemEval2023/SemEval2022-Task10/re_run

# %%
import pandas as pd

data = pd.read_csv("../Data/starting_ki/train_all_tasks.csv")
# dfa = pd.read_csv("Data/dev_task_a_entries.csv")
# dfb = pd.read_csv("Data/dev_task_b_entries.csv")
# dfc = pd.read_csv("Data/dev_task_c_entries.csv")

# %%
import json

# with open('../Results/TaskB/lexicon_pmi.json') as fin:
#     lexicon_pmi = json.load(fin)

# with open('../Results/TaskB/lexicon_shapley.json') as fin:
#     lexicon_shapley = json.load(fin)

# with open('../Results/TaskB/lexicon_shapley_augmented_v2_shap.json') as fin:
#     lexicon_shapley_augmented_v2_shap = json.load(fin)

# with open('../Results/TaskB/lexicon_shapley_augmented_v3_gptj.json') as fin:
#     lexicon_shapley_augmented_v3_gptj = json.load(fin)

# with open('../Results/TaskB/lexicon_shapley_augmented_v4_tweetbert.json') as fin:
#     lexicon_shapley_augmented_v4_tweetbert = json.load(fin)

# %%
data
# Out:
#                       rewire_id  \
# 0       sexism2022_english-7358
# 1       sexism2022_english-2367
# 2       sexism2022_english-3073
# 3      sexism2022_english-14895
# 4       sexism2022_english-4118
# ...                         ...
# 13995  sexism2022_english-14185
# 13996  sexism2022_english-18629
# 13997   sexism2022_english-3320
# 13998  sexism2022_english-13309
# 13999  sexism2022_english-12402
#
#                                                     text label_sexist  \
# 0                  Damn, this writing was pretty chaotic   not sexist
# 1      Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2           How the FUCK is this woman still an MP!!!???   not sexist
# 3      Understand. Know you're right. At same time I ...   not sexist
# 4         Surprized they didn't stop and rape some women   not sexist
# ...                                                  ...          ...
# 13995  complexes like the 'nice chicks' that go after...       sexist
# 13996  "GRAPHIC Germany - Muslim "refugee" stabbing h...   not sexist
# 13997  Lol I imagine there would be simps that are li...   not sexist
# 13998  It's not, the girls I go on dates with don't k...   not sexist
# 13999  How can he be an incel? He does have a girlfri...   not sexist
#
#       label_category             label_vector
# 0               none                     none
# 1               none                     none
# 2               none                     none
# 3               none                     none
# 4               none                     none
# ...              ...                      ...
# 13995  2. derogation  2.1 descriptive attacks
# 13996           none                     none
# 13997           none                     none
# 13998           none                     none
# 13999           none                     none
#
# [14000 rows x 5 columns]

# %%
task = "1b"

# %%
if not task.endswith("a"):
  data = data[data["label_category"]!="none"]

# %%
if task.endswith("a"):
  label_column = "label_sexist"
elif task.endswith("b"):
  label_column = "label_category"
elif task.endswith("c"):
  label_column = "label_vector"


label_column
# Out:
# 'label_category'

# %%
len(data)
# Out:
# 3398

# %%
data[["text", label_column]].groupby(label_column).count()
# Out:
#                                           text
# label_category
# 1. threats, plans to harm and incitement   310
# 2. derogation                             1590
# 3. animosity                              1165
# 4. prejudiced discussions                  333

# %%
# label_values = data[label_column].unique()
# label_values
if label_column == "label_sexist":
  label_values = [
      'sexist',
      'not sexist',
  ]

  label_map = {
      0: 'not sexist',
      1: 'sexist', 
      'not sexist':0,
      'sexist':1,
  }
elif label_column == "label_category":
  label_values = [
      '1. threats, plans to harm and incitement',
      '2. derogation',
      '3. animosity',
      '4. prejudiced discussions',
  ]

  label_map = {
      0: '1. threats, plans to harm and incitement',
      1: '2. derogation', 
      2: '3. animosity', 
      3: '4. prejudiced discussions',
      '1. threats, plans to harm and incitement':0,
      '2. derogation':1,
      '3. animosity':2,
      '4. prejudiced discussions':3,
  }
elif label_column == "label_vector":
  label_values = [
      '1.1 threats of harm',
      '1.2 incitement and encouragement of harm',
      '2.1 descriptive attacks',
      '2.2 aggressive and emotive attacks',
      '2.3 dehumanising attacks & overt sexual objectification',
      '3.1 casual use of gendered slurs, profanities, and insults',
      '3.2 immutable gender differences and gender stereotypes',
      '3.3 backhanded gendered compliments',
      '3.4 condescending explanations or unwelcome advice',
      '4.1 supporting mistreatment of individual women',
      '4.2 supporting systemic discrimination against women as a group',
  ]

  label_map = {
      0: '1.1 threats of harm',
      1: '1.2 incitement and encouragement of harm',
      2: '2.1 descriptive attacks',
      3: '2.2 aggressive and emotive attacks',
      4: '2.3 dehumanising attacks & overt sexual objectification',
      5: '3.1 casual use of gendered slurs, profanities, and insults',
      6: '3.2 immutable gender differences and gender stereotypes',
      7: '3.3 backhanded gendered compliments',
      8: '3.4 condescending explanations or unwelcome advice',
      9: '4.1 supporting mistreatment of individual women',
      10: '4.2 supporting systemic discrimination against women as a group',
      '1.1 threats of harm': 0,
      '1.2 incitement and encouragement of harm': 1,
      '2.1 descriptive attacks': 2,
      '2.2 aggressive and emotive attacks': 3,
      '2.3 dehumanising attacks & overt sexual objectification': 4,
      '3.1 casual use of gendered slurs, profanities, and insults': 5,
      '3.2 immutable gender differences and gender stereotypes': 6,
      '3.3 backhanded gendered compliments': 7,
      '3.4 condescending explanations or unwelcome advice': 8,
      '4.1 supporting mistreatment of individual women': 9,
      '4.2 supporting systemic discrimination against women as a group': 10,
  }
else:
  raise Exception("Unknown label column")

# %% [markdown]
# # Prepare Data

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 66.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 20.9 MB/s eta 0:00:00

# %%
import transformers

# %%
from transformers import BertTokenizer
from transformers import AutoModel, AutoTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# tokenizer = AutoTokenizer.from_pretrained("vinai/bertweet-large")

# print('Original Text: ', texts[0], '\n')
# print('Tokenized Text: ', tokenizer.tokenize(texts[0]), '\n')
# print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(texts[0])))
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# !pip3 install -q nltk emoji==0.6.0

# %%
# from emoji import demojize
# from nltk.tokenize import TweetTokenizer


# nltktokenizer = TweetTokenizer()


# def normalizeToken(token):
#     lowercased_token = token.lower()
#     if token.startswith("@"):
#         return "@USER"
#     elif lowercased_token.startswith("http") or lowercased_token.startswith("www"):
#         return "HTTPURL"
#     elif len(token) == 1:
#         return demojize(token)
#     else:
#         if token == "’":
#             return "'"
#         elif token == "…":
#             return "..."
#         else:
#             return token


# def normalizeTweet(tweet):
#     tokens = nltktokenizer.tokenize(tweet.replace("’", "'").replace("…", "..."))
#     normTweet = " ".join([normalizeToken(token) for token in tokens])

#     normTweet = (
#         normTweet.replace("cannot ", "can not ")
#         .replace("n't ", " n't ")
#         .replace("n 't ", " n't ")
#         .replace("ca n't", "can't")
#         .replace("ai n't", "ain't")
#     )
#     normTweet = (
#         normTweet.replace("'m ", " 'm ")
#         .replace("'re ", " 're ")
#         .replace("'s ", " 's ")
#         .replace("'ll ", " 'll ")
#         .replace("'d ", " 'd ")
#         .replace("'ve ", " 've ")
#     )
#     normTweet = (
#         normTweet.replace(" p . m .", "  p.m.")
#         .replace(" p . m ", " p.m ")
#         .replace(" a . m .", " a.m.")
#         .replace(" a . m ", " a.m ")
#     )

#     return " ".join(normTweet.split())

# %%
# normalizeTweet("DHEC confirms https://postandcourier.com/health/covid19/sc-has-first-two-presumptive-cases-of-coronavirus-dhec-confirms/article_bddfe4ae-5fd3-11ea-9ce4-5f495366cee6.html?utm_medium=social&utm_source=twitter&utm_campaign=user-share… via @postandcourier 😢")

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# from nltk.tokenize import  word_tokenize

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from nltk.tokenize import TweetTokenizer
nltktokenizer = TweetTokenizer()

def word_tokenize(sent):
  sent = sent.lower()
  words = nltktokenizer.tokenize(sent)
  return words

def label_to_number(label_map, label):
  return label_map[label]

def get_tensor(df, lexicons):
  texts = df['text'].values
  labels = [label_to_number(label_map, d) for d in df[label_column].values]

  text_ids = [tokenizer.encode(text, max_length=100, padding='max_length', truncation=True) for text in texts]
  text_ids_lengths = [len(text_ids[i]) for i in range(len(text_ids))]

  att_masks = []
  for ids in text_ids:
      masks = [int(id > 0) for id in ids]
      att_masks.append(masks)

  lexcon_emb = []
  for text in texts:
    words = word_tokenize(text)

    embs = []
    for w in words:
      e = []
      for label in lexicons:
        if w in lexicons[label]:
          e.append(1.0)
        else:
          e.append(0.0)
      embs.append(e)

    while len(embs) < 100:
      embs.append([0 for l in lexicons])
    lexcon_emb.append(embs)

  tensor_x = torch.tensor(text_ids)
  tensor_y = torch.tensor(labels)
  tensor_m = torch.tensor(att_masks)
  tensor_l = torch.tensor(lexcon_emb)

  return tensor_x, tensor_y, tensor_m, tensor_l


def get_loader(train, test, val, lexicons, batch_size=32):
  
  train_x, train_y, train_m, train_l = get_tensor(train, lexicons)
  test_x, test_y, test_m, test_l = get_tensor(test, lexicons)
  val_x, val_y, val_m, val_l = get_tensor(train, lexicons)

  train_data = TensorDataset(train_x, train_m, train_y, train_l)
  train_sampler = RandomSampler(train_data)
  train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

  val_data = TensorDataset(val_x, val_m, val_y, val_l)
  val_sampler = SequentialSampler(val_data)
  val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=batch_size)

  test_data = TensorDataset(test_x, test_m, test_y, test_l)
  test_sampler = SequentialSampler(test_data)
  test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

  return train_dataloader, test_dataloader, val_dataloader

# %% [markdown]
# ## Load Model

# %%
from transformers import BertForSequenceClassification
from transformers import BertPreTrainedModel, BertModel
from typing import List, Optional, Tuple, Union

import torch
import torch.utils.checkpoint
from torch import nn
from torch.nn import BCEWithLogitsLoss, CrossEntropyLoss, MSELoss
from transformers.modeling_outputs import SequenceClassifierOutput


class CustomBertForSequenceClassification(BertForSequenceClassification):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.config = config

        self.bert = BertModel(config)
        classifier_dropout = (
            config.classifier_dropout if config.classifier_dropout is not None else config.hidden_dropout_prob
        )
        self.dropout = nn.Dropout(classifier_dropout)
        self.classifier = nn.Linear(in_features=config.hidden_size+config.num_labels, out_features=config.num_labels)
        self.lstm = nn.LSTM(input_size=config.num_labels, hidden_size=config.num_labels, num_layers=1, batch_first=True)

        # Initialize weights and apply final processing
        self.post_init()

    def forward(
        self,
        input_ids: Optional[torch.Tensor] = None,
        attention_mask: Optional[torch.Tensor] = None,
        token_type_ids: Optional[torch.Tensor] = None,
        position_ids: Optional[torch.Tensor] = None,
        head_mask: Optional[torch.Tensor] = None,
        inputs_embeds: Optional[torch.Tensor] = None,
        labels: Optional[torch.Tensor] = None,
        output_attentions: Optional[bool] = None,
        output_hidden_states: Optional[bool] = None,
        return_dict: Optional[bool] = None,
        lexicon_emb: Optional[torch.Tensor] = None
    ) -> Union[Tuple[torch.Tensor], SequenceClassifierOutput]:

        r"""
        labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
            Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
            config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
            `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

        pooled_output = outputs[1]
        pooled_output = self.dropout(pooled_output)

        lstm_output, (ht, ct) = self.lstm(lexicon_emb)
        ht = torch.squeeze(ht, dim=0)
        
        concated_ouput = torch.cat((pooled_output, ht), 1)
        
        logits = self.classifier(concated_ouput)

        loss = None
        if labels is not None:
            if self.config.problem_type is None:
                if self.num_labels == 1:
                    self.config.problem_type = "regression"
                elif self.num_labels > 1 and (labels.dtype == torch.long or labels.dtype == torch.int):
                    self.config.problem_type = "single_label_classification"
                else:
                    self.config.problem_type = "multi_label_classification"

            if self.config.problem_type == "regression":
                loss_fct = MSELoss()
                if self.num_labels == 1:
                    loss = loss_fct(logits.squeeze(), labels.squeeze())
                else:
                    loss = loss_fct(logits, labels)
            elif self.config.problem_type == "single_label_classification":
                loss_fct = CrossEntropyLoss()
                loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
            elif self.config.problem_type == "multi_label_classification":
                loss_fct = BCEWithLogitsLoss()
                loss = loss_fct(logits, labels)
        if not return_dict:
            output = (logits,) + outputs[2:]
            return ((loss,) + output) if loss is not None else output

        return SequenceClassifierOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions,
        )

# %%
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import AutoModel, AutoTokenizer

# num_labels = len(set(labels))

# model = CustomBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels, output_attentions=False, output_hidden_states=False)
# model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels, output_attentions=False, output_hidden_states=False)
# model = BertForSequenceClassification.from_pretrained("vinai/bertweet-large", num_labels=num_labels, output_attentions=False, output_hidden_states=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = model.to(device)

# print(device)

# %%
# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# print('Number of trainable parameters:', count_parameters(model), '\n', model)

# %% [markdown]
# ## Fine-tune

# %%
from transformers import get_linear_schedule_with_warmup
import time
import numpy as np
import random
from tqdm.notebook import tqdm
import os


def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs


def run(train_dataloader, val_dataloader, model, optimizer, scheduler, num_epochs=5, add_lexicon=True, tmp_out_dir="/content/Models/_tmp"):
  train_losses = []
  val_losses = []
  num_mb_train = len(train_dataloader)
  num_mb_val = len(val_dataloader)

  if num_mb_val == 0:
      num_mb_val = 1

  best_loss = None

  for n in range(num_epochs):
      train_loss = 0
      val_loss = 0
      start_time = time.time()
      
      # for k, (mb_x, mb_m, mb_y, mb_l) in enumerate(train_dataloader):
      for k, (mb_x, mb_m, mb_y, mb_l) in tqdm(enumerate(train_dataloader), total=len(train_dataloader)):
          optimizer.zero_grad()
          model.train()
          
          mb_x = mb_x.to(device)
          mb_m = mb_m.to(device)
          mb_y = mb_y.to(device)
          mb_l = mb_l.to(device)
          
          if add_lexicon:
            outputs = model(mb_x, attention_mask=mb_m, labels=mb_y, lexicon_emb=mb_l)
          else:
            outputs = model(mb_x, attention_mask=mb_m, labels=mb_y)
          
          loss = outputs[0]
          #loss = model_loss(outputs[1], mb_y)
          loss.backward()
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
          optimizer.step()
          scheduler.step()
          
          train_loss += loss.data / num_mb_train
      
      print ("\nTrain loss after itaration %i: %f" % (n+1, train_loss))
      train_losses.append(train_loss.cpu())
      
      with torch.no_grad():
          model.eval()
          
          for k, (mb_x, mb_m, mb_y, mb_l) in enumerate(val_dataloader):
              mb_x = mb_x.to(device)
              mb_m = mb_m.to(device)
              mb_y = mb_y.to(device)
              mb_l = mb_l.to(device)
          
              if add_lexicon:
                outputs = model(mb_x, attention_mask=mb_m, labels=mb_y, lexicon_emb=mb_l)
              else:
                outputs = model(mb_x, attention_mask=mb_m, labels=mb_y)
              
              loss = outputs[0]
              #loss = model_loss(outputs[1], mb_y)
              
              val_loss += loss.data / num_mb_val

          if best_loss is None or best_loss >= val_loss:
              
              if not os.path.exists(tmp_out_dir):
                  os.makedirs(tmp_out_dir)
                  
              model.save_pretrained(tmp_out_dir)
              # tokenizer.save_pretrained(tmp_out_dir)

              best_loss = val_loss

          print("Validation loss after itaration %i: %f" % (n+1, val_loss))
          val_losses.append(val_loss.cpu())
      
      end_time = time.time()
      epoch_mins, epoch_secs = epoch_time(start_time, end_time)
      print(f'Time: {epoch_mins}m {epoch_secs}s')

  if add_lexicon:
    model = CustomBertForSequenceClassification.from_pretrained(tmp_out_dir)
  else:
    model = BertForSequenceClassification.from_pretrained(tmp_out_dir)

  model = model.to(device)
  return model, train_losses, val_losses

def fine_tune(train_dataloader, val_dataloader, seed_val = 42, num_epochs=5, add_lexicon=True, tmp_out_dir="/content/Models/_tmp"):
  random.seed(seed_val)
  np.random.seed(seed_val)
  torch.manual_seed(seed_val)
  torch.cuda.manual_seed_all(seed_val)

  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

  num_labels = len(label_values)
  if add_lexicon:
    model = CustomBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels, output_attentions=False, output_hidden_states=False)
  else:
    model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels, output_attentions=False, output_hidden_states=False)

  model = model.to(device)

  learning_rate = 1e-5
  adam_epsilon = 1e-8

  no_decay = ['bias', 'LayerNorm.weight']
  optimizer_grouped_parameters = [
      {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
      'weight_decay_rate': 0.2},
      {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
      'weight_decay_rate': 0.0}
  ]

  optimizer = torch.optim.AdamW(optimizer_grouped_parameters, lr=learning_rate, eps=adam_epsilon)

  total_steps = len(train_dataloader) * num_epochs
  scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
  return run(train_dataloader, val_dataloader, model, optimizer, scheduler, num_epochs, add_lexicon, tmp_out_dir)

# %%
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support

def get_prediction(model, test_dataloader, add_lexicon = True):
  outputs = []
  test_y = []
  with torch.no_grad():
      model.eval()
      for k, (mb_x, mb_m, mb_y, mb_l) in enumerate(test_dataloader):
          mb_x = mb_x.to(device)
          mb_m = mb_m.to(device)
          mb_l = mb_l.to(device)
          if add_lexicon:
            output = model(mb_x, attention_mask=mb_m, lexicon_emb=mb_l)
          else:
            output = model(mb_x, attention_mask=mb_m)
          outputs.append(output[0].to('cpu'))
          test_y.append(mb_y)

  outputs = torch.cat(outputs)


  _, predicted_values = torch.max(outputs, 1)
  predicted_values = predicted_values.numpy()
  true_values = torch.concat(test_y).numpy()

  test_accuracy = np.sum(predicted_values == true_values) / len(true_values)

  # print(classification_report(true_values, predicted_values, target_names=[str(l) for l in label_values]))
  p, r, f1, sup = precision_recall_fscore_support(true_values, predicted_values, average="macro")

  return f1, p, r

# %%
# !pip install numba

# %%
from numba import cuda

def train_with_lexicons(i, lex_path=None, num_epochs=5, add_lexicon=True):
  
  # d = cuda.get_current_device() 
  # d.reset()

  train = pd.read_csv(f"Data/{i}_train.csv")
  test = pd.read_csv(f"Data/{i}_test.csv")
  val = pd.read_csv(f"Data/{i}_val.csv")

  if lex_path is None:
    lexicons = {}
    for l in label_values:
      lexicons[l] = {}
  else:
    with open(f'{lex_path}_{i}.json') as fin:
      lexicons = json.load(fin)

  train_dataloader, test_dataloader, val_dataloader = get_loader(train,test, val, lexicons, batch_size=32)
  model, train_losses, val_losses = fine_tune(train_dataloader, val_dataloader, num_epochs=num_epochs, add_lexicon=add_lexicon, tmp_out_dir="/content/Models/_tmp")
  f1, p, r = get_prediction(model, test_dataloader, add_lexicon=add_lexicon)
  print(f1, p, r)
  # all_f1.append(f1)
  # all_p.append(p)
  # all_r.append(r)
  
  # print(f"F1:{np.mean(all_f1):.3f}±{np.std(all_f1):.3f}")
  # print(f"P:{np.mean(all_p):.3f}±{np.std(all_p):.3f}, R: {np.mean(all_r):.3f}±{np.std(all_r):.3f}")

# train_with_lexicons("Results/TaskB/lexicon_pmi_train")

# %%
# train_with_lexicons(0, None, num_epochs=10, add_lexicon=False)

# %%
train_with_lexicons(0, None, num_epochs=10, add_lexicon=False)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.217937
# Validation loss after itaration 1: 1.071049
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.052872
# Validation loss after itaration 2: 0.938358
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.936738
# Validation loss after itaration 3: 0.792023
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.821377
# Validation loss after itaration 4: 0.655823
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.706883
# Validation loss after itaration 5: 0.554956
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.611228
# Validation loss after itaration 6: 0.453134
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.530521
# Validation loss after itaration 7: 0.377338
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.485367
# Validation loss after itaration 8: 0.350797
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.435326
# Validation loss after itaration 9: 0.305802
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.412034
# Validation loss after itaration 10: 0.299396
# Time: 0m 58s
# 0.5610985747326686 0.5906570063923006 0.5395066358545241

# %%
train_with_lexicons(1, None, num_epochs=10, add_lexicon=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.228713
# Validation loss after itaration 1: 1.083361
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.057767
# Validation loss after itaration 2: 0.936938
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.938366
# Validation loss after itaration 3: 0.804050
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.814829
# Validation loss after itaration 4: 0.658291
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.707027
# Validation loss after itaration 5: 0.575308
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.620448
# Validation loss after itaration 6: 0.463833
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.549441
# Validation loss after itaration 7: 0.398813
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.487755
# Validation loss after itaration 8: 0.349619
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.444703
# Validation loss after itaration 9: 0.325418
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.423163
# Validation loss after itaration 10: 0.309629
# Time: 0m 58s
# 0.6217721647595787 0.6560709433516451 0.6116666327982118

# %%
train_with_lexicons(2, None, num_epochs=10, add_lexicon=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.230380
# Validation loss after itaration 1: 1.086409
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.062759
# Validation loss after itaration 2: 0.954425
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.951418
# Validation loss after itaration 3: 0.807781
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.824268
# Validation loss after itaration 4: 0.657861
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.714462
# Validation loss after itaration 5: 0.541621
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.616525
# Validation loss after itaration 6: 0.451166
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.537411
# Validation loss after itaration 7: 0.379699
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.482227
# Validation loss after itaration 8: 0.344708
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.439442
# Validation loss after itaration 9: 0.305573
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.411696
# Validation loss after itaration 10: 0.295428
# Time: 0m 58s
# 0.5445688535551888 0.5585744321038439 0.5343083061806333

# %%
train_with_lexicons(3, None, num_epochs=10, add_lexicon=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.220191
# Validation loss after itaration 1: 1.110004
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.062665
# Validation loss after itaration 2: 0.955101
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.946166
# Validation loss after itaration 3: 0.811266
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.825282
# Validation loss after itaration 4: 0.689522
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.709738
# Validation loss after itaration 5: 0.552364
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.611791
# Validation loss after itaration 6: 0.456085
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.549783
# Validation loss after itaration 7: 0.389292
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.479177
# Validation loss after itaration 8: 0.356731
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.436018
# Validation loss after itaration 9: 0.313151
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.412458
# Validation loss after itaration 10: 0.301341
# Time: 0m 58s
# 0.5440524979815403 0.5780884338102227 0.5214651546557727

# %%
train_with_lexicons(4, None, num_epochs=10, add_lexicon=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.231016
# Validation loss after itaration 1: 1.089339
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.063592
# Validation loss after itaration 2: 0.933489
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.934029
# Validation loss after itaration 3: 0.805403
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.809114
# Validation loss after itaration 4: 0.650003
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.702462
# Validation loss after itaration 5: 0.545323
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.611616
# Validation loss after itaration 6: 0.458981
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.536318
# Validation loss after itaration 7: 0.394132
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.471696
# Validation loss after itaration 8: 0.353623
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.434511
# Validation loss after itaration 9: 0.315143
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.412587
# Validation loss after itaration 10: 0.303210
# Time: 0m 58s
# 0.5705684578585308 0.5831040168819325 0.5604036612307381

# %%
train_with_lexicons(0, "Results/TaskB/lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.184608
# Validation loss after itaration 1: 1.071873
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.048924
# Validation loss after itaration 2: 0.932159
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.910290
# Validation loss after itaration 3: 0.797289
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.804788
# Validation loss after itaration 4: 0.674075
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.696474
# Validation loss after itaration 5: 0.565864
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.612622
# Validation loss after itaration 6: 0.472228
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.533771
# Validation loss after itaration 7: 0.405312
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.473286
# Validation loss after itaration 8: 0.359408
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.441114
# Validation loss after itaration 9: 0.328647
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.404648
# Validation loss after itaration 10: 0.316410
# Time: 0m 58s
# 0.5824594731509625 0.6034104199893673 0.5662731066411806

# %%
train_with_lexicons(1, "Results/TaskB/lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.199636
# Validation loss after itaration 1: 1.100130
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.072963
# Validation loss after itaration 2: 0.992399
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.964113
# Validation loss after itaration 3: 0.852139
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.857640
# Validation loss after itaration 4: 0.734446
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.757599
# Validation loss after itaration 5: 0.630460
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.670997
# Validation loss after itaration 6: 0.560563
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.602777
# Validation loss after itaration 7: 0.479755
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.543747
# Validation loss after itaration 8: 0.429737
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.497234
# Validation loss after itaration 9: 0.403710
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.467184
# Validation loss after itaration 10: 0.389467
# Time: 0m 58s
# 0.6257934044308708 0.6319799191313434 0.6346297500508027

# %%
train_with_lexicons(2, "Results/TaskB/lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.179695
# Validation loss after itaration 1: 1.081370
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.069030
# Validation loss after itaration 2: 0.968075
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.952013
# Validation loss after itaration 3: 0.835237
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.847907
# Validation loss after itaration 4: 0.717097
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.747179
# Validation loss after itaration 5: 0.623606
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.666453
# Validation loss after itaration 6: 0.538890
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.590445
# Validation loss after itaration 7: 0.469414
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.529464
# Validation loss after itaration 8: 0.423642
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.492159
# Validation loss after itaration 9: 0.387243
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.466318
# Validation loss after itaration 10: 0.377040
# Time: 0m 58s
# 0.5465712162167525 0.5438430149581261 0.5565640273393748

# %%
train_with_lexicons(3, "Results/TaskB/lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.175364
# Validation loss after itaration 1: 1.089303
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.060955
# Validation loss after itaration 2: 0.961033
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.946058
# Validation loss after itaration 3: 0.824165
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.827320
# Validation loss after itaration 4: 0.700340
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.725949
# Validation loss after itaration 5: 0.610480
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.634729
# Validation loss after itaration 6: 0.515625
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.559619
# Validation loss after itaration 7: 0.435695
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.493648
# Validation loss after itaration 8: 0.380761
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.446561
# Validation loss after itaration 9: 0.351966
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.419312
# Validation loss after itaration 10: 0.341820
# Time: 0m 58s
# 0.5655691511717884 0.5910097497176149 0.5492569076895213

# %%
train_with_lexicons(4, "Results/TaskB/lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.183284
# Validation loss after itaration 1: 1.085811
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.062569
# Validation loss after itaration 2: 0.956854
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.946694
# Validation loss after itaration 3: 0.824777
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.835725
# Validation loss after itaration 4: 0.722989
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.757720
# Validation loss after itaration 5: 0.630628
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.673319
# Validation loss after itaration 6: 0.546954
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.604624
# Validation loss after itaration 7: 0.482407
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.548587
# Validation loss after itaration 8: 0.436729
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.504215
# Validation loss after itaration 9: 0.407193
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.488226
# Validation loss after itaration 10: 0.397082
# Time: 0m 58s
# 0.573477894602993 0.594847670250896 0.5618763120021266

# %%
train_with_lexicons(0, "Results/TaskB/augmented_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.184608
# Validation loss after itaration 1: 1.071873
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.048924
# Validation loss after itaration 2: 0.932159
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.910289
# Validation loss after itaration 3: 0.797290
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.804787
# Validation loss after itaration 4: 0.674101
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.696447
# Validation loss after itaration 5: 0.566050
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.612283
# Validation loss after itaration 6: 0.471723
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.533125
# Validation loss after itaration 7: 0.404427
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.472587
# Validation loss after itaration 8: 0.358880
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.440345
# Validation loss after itaration 9: 0.327987
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.403921
# Validation loss after itaration 10: 0.315677
# Time: 0m 58s
# 0.5818092739544627 0.6011828227212843 0.5668647412036462

# %%
train_with_lexicons(1, "Results/TaskB/augmented_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.199636
# Validation loss after itaration 1: 1.100130
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.072963
# Validation loss after itaration 2: 0.992399
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.964113
# Validation loss after itaration 3: 0.852139
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.857642
# Validation loss after itaration 4: 0.734444
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.757604
# Validation loss after itaration 5: 0.630479
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.671037
# Validation loss after itaration 6: 0.560468
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.602852
# Validation loss after itaration 7: 0.479540
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.543735
# Validation loss after itaration 8: 0.429249
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.497234
# Validation loss after itaration 9: 0.404005
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.467355
# Validation loss after itaration 10: 0.389359
# Time: 0m 58s
# 0.6257934044308708 0.6319799191313434 0.6346297500508027

# %%
train_with_lexicons(2, "Results/TaskB/augmented_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.179695
# Validation loss after itaration 1: 1.081371
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.069030
# Validation loss after itaration 2: 0.968075
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.952030
# Validation loss after itaration 3: 0.835123
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.847449
# Validation loss after itaration 4: 0.717505
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.747391
# Validation loss after itaration 5: 0.623535
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.666135
# Validation loss after itaration 6: 0.538988
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.589926
# Validation loss after itaration 7: 0.469563
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.529609
# Validation loss after itaration 8: 0.423630
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.492243
# Validation loss after itaration 9: 0.387307
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.466683
# Validation loss after itaration 10: 0.376997
# Time: 0m 58s
# 0.5481884057971015 0.5460310222064984 0.5581168223704307

# %%
train_with_lexicons(3, "Results/TaskB/augmented_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.175364
# Validation loss after itaration 1: 1.089303
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.060955
# Validation loss after itaration 2: 0.961034
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.946059
# Validation loss after itaration 3: 0.824169
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.827321
# Validation loss after itaration 4: 0.700333
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.725753
# Validation loss after itaration 5: 0.610464
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.634649
# Validation loss after itaration 6: 0.515807
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.559505
# Validation loss after itaration 7: 0.435666
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.493825
# Validation loss after itaration 8: 0.380891
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.446577
# Validation loss after itaration 9: 0.352138
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.419347
# Validation loss after itaration 10: 0.342054
# Time: 0m 58s
# 0.5655691511717884 0.5910097497176149 0.5492569076895213

# %%
train_with_lexicons(4, "Results/TaskB/augmented_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.bias_hh_l0', 'lstm.weight_ih_l0', 'lstm.weight_hh_l0', 'lstm.bias_ih_l0', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.183284
# Validation loss after itaration 1: 1.085812
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.062530
# Validation loss after itaration 2: 0.956364
# Time: 0m 57s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.945537
# Validation loss after itaration 3: 0.824893
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.834323
# Validation loss after itaration 4: 0.718551
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.754250
# Validation loss after itaration 5: 0.627000
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.670790
# Validation loss after itaration 6: 0.541306
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.601081
# Validation loss after itaration 7: 0.476717
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.544155
# Validation loss after itaration 8: 0.430709
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.499866
# Validation loss after itaration 9: 0.401284
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.483203
# Validation loss after itaration 10: 0.391169
# Time: 0m 58s
# 0.5777733398192384 0.5966836929206154 0.5667851479067549

# %%
train_with_lexicons(0, "Results/TaskB/gptj_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.184609
# Validation loss after itaration 1: 1.071852
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.048838
# Validation loss after itaration 2: 0.931826
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.909405
# Validation loss after itaration 3: 0.790849
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.801285
# Validation loss after itaration 4: 0.673544
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.695287
# Validation loss after itaration 5: 0.564415
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.610840
# Validation loss after itaration 6: 0.469806
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.531709
# Validation loss after itaration 7: 0.401828
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.470302
# Validation loss after itaration 8: 0.356911
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.437867
# Validation loss after itaration 9: 0.324506
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.400469
# Validation loss after itaration 10: 0.312785
# Time: 0m 58s
# 0.5908443268600176 0.6085412335412336 0.5765115358136911

# %%
train_with_lexicons(1, "Results/TaskB/gptj_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.199783
# Validation loss after itaration 1: 1.097566
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.072519
# Validation loss after itaration 2: 0.995947
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.964895
# Validation loss after itaration 3: 0.854700
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.854199
# Validation loss after itaration 4: 0.735602
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.759247
# Validation loss after itaration 5: 0.630756
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.675214
# Validation loss after itaration 6: 0.565898
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.605652
# Validation loss after itaration 7: 0.483084
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.548649
# Validation loss after itaration 8: 0.434044
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.503874
# Validation loss after itaration 9: 0.407478
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.477211
# Validation loss after itaration 10: 0.395476
# Time: 0m 58s
# 0.6212996068540909 0.6315740740740741 0.6308440357650884

# %%
train_with_lexicons(2, "Results/TaskB/gptj_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.179695
# Validation loss after itaration 1: 1.081372
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.069023
# Validation loss after itaration 2: 0.968141
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.952097
# Validation loss after itaration 3: 0.836004
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.847089
# Validation loss after itaration 4: 0.717235
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.748730
# Validation loss after itaration 5: 0.622753
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.667761
# Validation loss after itaration 6: 0.540856
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.592005
# Validation loss after itaration 7: 0.470478
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.530332
# Validation loss after itaration 8: 0.424724
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.492807
# Validation loss after itaration 9: 0.388314
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.467599
# Validation loss after itaration 10: 0.378041
# Time: 0m 58s
# 0.5471282593375616 0.5439362621875422 0.5581168223704307

# %%
train_with_lexicons(3, "Results/TaskB/gptj_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.175407
# Validation loss after itaration 1: 1.089400
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.059942
# Validation loss after itaration 2: 0.956613
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.941415
# Validation loss after itaration 3: 0.816210
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.818515
# Validation loss after itaration 4: 0.692551
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.717377
# Validation loss after itaration 5: 0.601603
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.626166
# Validation loss after itaration 6: 0.506693
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.550445
# Validation loss after itaration 7: 0.423327
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.483451
# Validation loss after itaration 8: 0.368389
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.435395
# Validation loss after itaration 9: 0.338998
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.407126
# Validation loss after itaration 10: 0.328852
# Time: 0m 58s
# 0.5676031758431621 0.5906437113333665 0.5530914384227862

# %%
train_with_lexicons(4, "Results/TaskB/gptj_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.183286
# Validation loss after itaration 1: 1.085619
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.061736
# Validation loss after itaration 2: 0.950901
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.947016
# Validation loss after itaration 3: 0.827379
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.839141
# Validation loss after itaration 4: 0.729273
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.761137
# Validation loss after itaration 5: 0.631947
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.678199
# Validation loss after itaration 6: 0.552761
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.611498
# Validation loss after itaration 7: 0.489344
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.554466
# Validation loss after itaration 8: 0.442293
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.510819
# Validation loss after itaration 9: 0.413004
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.494364
# Validation loss after itaration 10: 0.402659
# Time: 0m 58s
# 0.5594145308615776 0.5850318662818662 0.5459660231554052

# %%
train_with_lexicons(0, "Results/TaskB/bertweet_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.184608
# Validation loss after itaration 1: 1.071867
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.048911
# Validation loss after itaration 2: 0.932208
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.910389
# Validation loss after itaration 3: 0.797314
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.804619
# Validation loss after itaration 4: 0.676891
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.696737
# Validation loss after itaration 5: 0.566823
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.613295
# Validation loss after itaration 6: 0.473056
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.534869
# Validation loss after itaration 7: 0.406332
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.473920
# Validation loss after itaration 8: 0.360471
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.441663
# Validation loss after itaration 9: 0.329053
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.405124
# Validation loss after itaration 10: 0.316874
# Time: 0m 58s
# 0.5797066954572966 0.5992627960275019 0.5646908281601679

# %%
train_with_lexicons(1, "Results/TaskB/bertweet_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.199720
# Validation loss after itaration 1: 1.096467
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.075030
# Validation loss after itaration 2: 0.990662
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.965720
# Validation loss after itaration 3: 0.856709
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.858378
# Validation loss after itaration 4: 0.733324
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.758284
# Validation loss after itaration 5: 0.630888
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.673605
# Validation loss after itaration 6: 0.572094
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.606315
# Validation loss after itaration 7: 0.481970
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.547341
# Validation loss after itaration 8: 0.432805
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.502245
# Validation loss after itaration 9: 0.408199
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.472745
# Validation loss after itaration 10: 0.394085
# Time: 0m 58s
# 0.615457127935445 0.6262677784527563 0.622479374110953

# %%
train_with_lexicons(2, "Results/TaskB/bertweet_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.179695
# Validation loss after itaration 1: 1.081368
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.069026
# Validation loss after itaration 2: 0.967978
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.951882
# Validation loss after itaration 3: 0.835686
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.847424
# Validation loss after itaration 4: 0.718313
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.748488
# Validation loss after itaration 5: 0.624781
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.667264
# Validation loss after itaration 6: 0.540616
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.591103
# Validation loss after itaration 7: 0.470284
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.530544
# Validation loss after itaration 8: 0.424338
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.492800
# Validation loss after itaration 9: 0.388253
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.467176
# Validation loss after itaration 10: 0.377829
# Time: 0m 58s
# 0.5465712162167525 0.5438430149581261 0.5565640273393748

# %%
train_with_lexicons(3, "Results/TaskB/bertweet_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.175449
# Validation loss after itaration 1: 1.089470
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.060379
# Validation loss after itaration 2: 0.958142
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.943533
# Validation loss after itaration 3: 0.820558
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.822376
# Validation loss after itaration 4: 0.697091
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.720306
# Validation loss after itaration 5: 0.606411
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.630536
# Validation loss after itaration 6: 0.511041
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.555200
# Validation loss after itaration 7: 0.429504
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.488778
# Validation loss after itaration 8: 0.374493
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.440982
# Validation loss after itaration 9: 0.345320
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.412574
# Validation loss after itaration 10: 0.335359
# Time: 0m 58s
# 0.5717011732229124 0.5927745625389038 0.5582659166985302

# %%
train_with_lexicons(4, "Results/TaskB/bertweet_lexicon_shapley_train", num_epochs=10, add_lexicon=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing CustomBertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CustomBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CustomBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['lstm.weight_ih_l0', 'lstm.bias_ih_l0', 'lstm.bias_hh_l0', 'classifier.weight', 'classifier.bias', 'lstm.weight_hh_l0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 1: 1.183286
# Validation loss after itaration 1: 1.085564
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 2: 1.062080
# Validation loss after itaration 2: 0.956482
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 3: 0.947213
# Validation loss after itaration 3: 0.826180
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 4: 0.836780
# Validation loss after itaration 4: 0.722560
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 5: 0.755555
# Validation loss after itaration 5: 0.625959
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 6: 0.670769
# Validation loss after itaration 6: 0.543493
# Time: 0m 59s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 7: 0.601365
# Validation loss after itaration 7: 0.476392
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 8: 0.543676
# Validation loss after itaration 8: 0.431990
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 9: 0.499089
# Validation loss after itaration 9: 0.401598
# Time: 0m 58s
#   0%|          | 0/85 [00:00<?, ?it/s]
# Train loss after itaration 10: 0.482816
# Validation loss after itaration 10: 0.391937
# Time: 0m 58s
# 0.5773326389230318 0.5996127010140759 0.5648319262253756

# %% [markdown]
# ### Results

# %%
results = {"None_train": [
[0.5610985747326686, 0.5906570063923006, 0.5395066358545241,],
[0.6217721647595787, 0.6560709433516451, 0.6116666327982118,],
[0.5445688535551888, 0.5585744321038439, 0.5343083061806333,],
[0.5440524979815403, 0.5780884338102227, 0.5214651546557727,],
[0.5705684578585308, 0.5831040168819325, 0.5604036612307381,],
],

"lexicon_shapley_train": [
[0.5824594731509625, 0.6034104199893673, 0.5662731066411806,],
[0.6257934044308708, 0.6319799191313434, 0.6346297500508027,],
[0.5465712162167525, 0.5438430149581261, 0.5565640273393748,],
[0.5655691511717884, 0.5910097497176149, 0.5492569076895213,],
[0.573477894602993, 0.594847670250896, 0.5618763120021266,],
],

"augmented_lexicon_shapley_train": [
[0.5818092739544627, 0.6011828227212843, 0.5668647412036462,],
[0.6257934044308708, 0.6319799191313434, 0.6346297500508027,],
[0.5481884057971015, 0.5460310222064984, 0.5581168223704307,],
[0.5655691511717884, 0.5910097497176149, 0.5492569076895213,],
[0.5777733398192384, 0.5966836929206154, 0.5667851479067549,],
],

"gptj_lexicon_shapley_train": [
[0.5908443268600176, 0.6085412335412336, 0.5765115358136911,],
[0.6212996068540909, 0.6315740740740741, 0.6308440357650884,],
[0.5471282593375616, 0.5439362621875422, 0.5581168223704307,],
[0.5676031758431621, 0.5906437113333665, 0.5530914384227862,],
[0.5594145308615776, 0.5850318662818662, 0.5459660231554052,],
],

"bertweet_lexicon_shapley_train": [
[0.5797066954572966, 0.5992627960275019, 0.5646908281601679,],
[0.615457127935445, 0.6262677784527563, 0.622479374110953,],
[0.5465712162167525, 0.5438430149581261, 0.5565640273393748,],
[0.5717011732229124, 0.5927745625389038, 0.5582659166985302,],
[0.5773326389230318, 0.5996127010140759, 0.5648319262253756,],
],
}

# %%
import numpy as np

for exp in results:
  aug_all_f1 = []
  aug_all_p = []
  aug_all_r = []
  for f1, p, r in results[exp]:
    aug_all_f1.append(f1)
    aug_all_p.append(p)
    aug_all_r.append(r)
  
  print(exp)
  print(f"F1:{np.mean(aug_all_f1):.3f} ± {np.std(aug_all_f1):.3f}")
  print(f"P:{np.mean(aug_all_p):.3f} ± {np.std(aug_all_p):.3f}")
  print(f"R:{np.mean(aug_all_r):.3f} ± {np.std(aug_all_r):.3f}")
  print("")
# Out:
# None_train
# F1:0.568 ± 0.029
# P:0.593 ± 0.033
# R:0.553 ± 0.032
#
# lexicon_shapley_train
# F1:0.579 ± 0.026
# P:0.593 ± 0.028
# R:0.574 ± 0.031
#
# augmented_lexicon_shapley_train
# F1:0.580 ± 0.026
# P:0.593 ± 0.028
# R:0.575 ± 0.030
#
# gptj_lexicon_shapley_train
# F1:0.577 ± 0.026
# P:0.592 ± 0.029
# R:0.573 ± 0.031
#
# bertweet_lexicon_shapley_train
# F1:0.578 ± 0.022
# P:0.592 ± 0.027
# R:0.573 ± 0.025

# %% [markdown]
# ## Create Submission

# %%
ls ../Data/starting_ki/train_all_tasks.csv

# %%
# dftrain = pd.read_csv("../Data/starting_ki/train_all_tasks.csv")
# dfdev = pd.read_csv("../Data/dev_task_b_entries.csv")
# dftest = pd.read_csv("../Data/test_task_b_entries.csv")

# %%
df = dftrain
texts = df['text'].values

# %%
text_ids = [tokenizer.encode(text, max_length=100, padding='max_length') for text in texts]

# %%
att_masks = []
for ids in text_ids:
    masks = [int(id > 0) for id in ids]
    att_masks.append(masks)

# %%
lexcon_emb = []
for text in texts:
  words = word_tokenize(text)

  embs = []
  for w in words:
    e = []
    for label in lexicons:
      if w in lexicons[label]:
        e.append(1.0)
      else:
        e.append(0.0)
    embs.append(e)

  while len(embs) < 100:
    embs.append([0 for l in lexicons])
  lexcon_emb.append(embs)

# %%
test_x = torch.tensor(text_ids);
test_m = torch.tensor(att_masks);
test_l = torch.tensor(lexcon_emb);

# %%
len(df), test_x.shape

# %%
from tqdm import tqdm
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

batch_size = 32
test_data = TensorDataset(test_x, test_m, test_l)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

outputs = []
with torch.no_grad():
    model.eval()
    for k, (mb_x, mb_m, mb_l) in tqdm(enumerate(test_dataloader), total=len(test_dataloader)):
        mb_x = mb_x.to(device)
        mb_m = mb_m.to(device)
        mb_l = mb_l.to(device)
        output = model(mb_x, attention_mask=mb_m, lexicon_emb=mb_l)
        outputs.append(output[0].to('cpu'))

outputs = torch.cat(outputs)
_, predicted_values = torch.max(outputs, 1)
predicted_values = predicted_values.numpy()

# %%
def number_to_label(label):
  return label_map[label]

predicted_labels = list(map(number_to_label, predicted_values))

# %%
len(predicted_labels)

# %%
df["label_pred"] = predicted_labels

# %%
df

# %%
# df[["rewire_id", "label_pred"]].to_csv(f"../Results/1b_lexbert_test.csv", index=False)

# %%
df.to_csv(f"../Results/1b_lexbert_train.csv", index=False)
